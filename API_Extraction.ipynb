# %%
#import libraraies
import requests
import pandas as pd
import time

# %%
#Keys
API_key = 'AIzaSyBZsUNTO5JKdMTFisA9Jcz9HBTvu1C0VL8'
Channel_ID = 'UCW8Ews7tdKKkBT6GdtQaXvQ'

# %%
#API call
pageToken = ''
url = 'https://www.googleapis.com/youtube/v3/search?key='+API_key+'&channelId='+Channel_ID+'&part=snippet,id&order=date&maxResults=100'+pageToken

response = requests.get(url).json()

# %%
response['items'][0]
# Out:
# {'etag': 'BdQq8d0hljfXZeIGjJIISfivcNg',
#  'id': {'kind': 'youtube#video', 'videoId': 'PlpUo6bHsBQ'},
#  'kind': 'youtube#searchResult',
#  'snippet': {'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#   'channelTitle': 'Nate at StrataScratch',
#   'description': 'This advanced SQL question is from the Facebook data science interview that tests your ability to write window functions and rank data and use some advanced ...',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-08-09T02:18:01Z',
#   'publishedAt': '2021-08-09T02:18:01Z',
#   'thumbnails': {'default': {'height': 90,
#     'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/default.jpg',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/hqdefault.jpg',
#     'width': 480},
#    'medium': {'height': 180,
#     'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/mqdefault.jpg',
#     'width': 320}},
#   'title': 'Advanced Facebook Data Science SQL interview question [RANK()]'}}

# %%
df = pd.DataFrame(columns=["video_id", "video_title", "upload_date"])

# %%
for video in response['items']:
  if video['id']['kind'] == 'youtube#video':

    video_id = video['id']['videoId']
    video_title = video['snippet']['title']
    upload_date = video['snippet']['publishedAt']
    
    df = df.append({'video_id':video_id,
                    'video_title':video_title,
                    'upload_data':upload_date},
                    ignore_index= True)

# %%
df
# Out:
#        video_id  ...           upload_data
# 0   PlpUo6bHsBQ  ...  2021-08-09T02:18:01Z
# 1   uY2wfR8Dkqo  ...  2021-07-26T03:43:39Z
# 2   yY7yau9j3xk  ...  2021-07-20T05:18:03Z
# 3   i-E4pdU2qXM  ...  2021-07-13T01:34:56Z
# 4   T1UhSuKqy3A  ...  2021-06-15T05:10:20Z
# 5   2iE3JgNTwVU  ...  2021-06-04T05:36:49Z
# 6   RgKMbpEylWA  ...  2021-05-24T05:01:10Z
# 7   giGIPINLqJs  ...  2021-05-13T06:23:40Z
# 8   77IVf0zgmwI  ...  2021-05-05T17:55:05Z
# 9   xtbMCAVXDmU  ...  2021-04-15T10:49:41Z
# 10  fklHBWow8vE  ...  2021-04-02T03:05:38Z
